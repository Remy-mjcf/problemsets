# %% [markdown]
# [![PracticeProbs](https://d33wubrfki0l68.cloudfront.net/b6800cc830e3fd5a3a4c3d9cfb1137e6a4c15c77/ec467/assets/images/transparent-1.png)](https://www.practiceprobs.com/)

# %% [markdown]
# # [Gone with the Wind](https://www.practiceprobs.com/problemsets/regular-expressions-in-python/beginner/gone-with-the-wind/)
#
# Here's a quote from [Gone with the Wind](https://en.wikipedia.org/wiki/Gone_with_the_Wind_(film)) 👫.

# %%
quote = "Frankly my dear, I don't give a darn."

# %% [markdown]
# Check if it contains
#
# - a lowercase letter
# - followed by a single space
# - followed by the letter g
#
# **Expected Result**
#
# Should return `True`.

# %% [markdown]
# ---

# %%
# Your brilliant solution here!
import re

pattern = re.compile(r'[a-z] g')

# %%
pattern.findall(quote)
# Out:
# ['t g']

# %% [markdown]
# ## [See our solution!](https://www.practiceprobs.com/problemsets/regular-expressions-in-python/beginner/gone-with-the-wind/solution/)
